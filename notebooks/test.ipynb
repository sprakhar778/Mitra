# %%
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(model="meta-llama/llama-4-scout-17b-16e-instruct")

import base64

def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

base64_image = encode_image("data/rag.jpeg")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe this image in detail."},
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{base64_image}"
            },
        },
    ]
)

response = llm.invoke([message])
print(response.content)
# Out:
# The image presents a visual representation of the RAG (Retrieval-Augmented Generation) model, comprising three distinct components. The image features three rectangular cards, each with a different color and letter, pinned to a corkboard.
#
# *   **Card 1: Retrieval (R)**
#     *   Color: Light blue
#     *   Letter: R in large blue font
#     *   Text: "RETRIEVAL" in smaller black font below the letter
# *   **Card 2: Augmented (A)**
#     *   Color: Pink
#     *   Letter: A in large red font
#     *   Text: "AUGMENTED" in smaller black font below the letter
# *   **Card 3: Generation (G)**
#     *   Color: Light yellow
#     *   Letter: G in large yellow font
#     *   Text: "GENERATION" in smaller black font below the letter
#
# The cards are arranged in a row, with each card featuring a pushpin at the top, holding it to the corkboard. The background of the image is a brown corkboard, providing a rustic and textured backdrop for the colorful cards. Overall, the image effectively conveys the three key components of the RAG model in a clear and visually appealing manner.

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 41
#      38 with open("data/rag.jpeg", "rb") as f:
#      39     image_bytes = f.read()
# ---> 41 asyncio.run(image_to_text.describe_image(image_bytes))
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/asyncio/runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
# /home/prakhar/C Drive/My Projects/Test Projects/Mitra/.venv/lib/python3.12/site-packages/pygments/regexopt.py:78: RuntimeWarning: coroutine 'ImageToText.describe_image' was never awaited
#   for group in groupby(strings, lambda s: s[0] == first[0])) \
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
