# %%
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(model="meta-llama/llama-4-scout-17b-16e-instruct")

import base64

def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

base64_image = encode_image("data/rag.jpeg")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe this image in detail."},
        {
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{base64_image}"
            },
        },
    ]
)

response = llm.invoke([message])
print(response.content)
# Out:
# The image presents a visual representation of the RAG (Retrieval-Augmented Generation) model, comprising three distinct components. The image features three rectangular pieces of paper, each with a different color and letter, pinned to a corkboard.
#
# *   **Leftmost Paper:**
#     *   Color: Light blue
#     *   Letter: R
#     *   Text: RETRIEVAL
# *   **Middle Paper:**
#     *   Color: Pink
#     *   Letter: A
#     *   Text: AUGMENTED
# *   **Rightmost Paper:**
#     *   Color: Light yellow
#     *   Letter: G
#     *   Text: GENERATION
#
# The papers are arranged in a horizontal row, with each paper overlapping the one below it slightly, creating a sense of depth. The background of the image is a corkboard, which provides a rustic and textured backdrop for the papers. Overall, the image effectively conveys the key components of the RAG model in a clear and visually appealing manner.

# %%
from google import genai
from google.genai import types
from PIL import Image
import os

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
client = genai.Client(api_key=GOOGLE_API_KEY)

prompt = ("Create a picture of a nano banana dish in a fancy restaurant with a Gemini theme")
response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[prompt],
)

for part in response.parts:
    if part.text is not None:
        print(part.text)
    elif part.inline_data is not None:
        image = part.as_image()
        image.save("generated_image.png")
# Out:
# AIzaSyA5ecVgbk9JRADUrf9AJxURm8VCJzlU_R4
# Here's a picture of a nano banana dish in a fancy restaurant with a Gemini theme.
